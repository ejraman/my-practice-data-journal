# %% [markdown]
# <a href="https://colab.research.google.com/github/ejraman/my-practice-data-journal/blob/main/mypractice.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("Hello, Good Morning GitHub! This is my practice commit.")
# Out:
# Hello, Good Morning GitHub! This is my practice commit.
